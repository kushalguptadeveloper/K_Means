# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
x, y = make_blobs()

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x[:,0],x[:,1],c = y)

# %%
from sklearn.metrics import silhouette_score

# %%
k_clusters = [2,3,4,5,6]
for cluster in k_clusters:
    clusterer = KMeans(n_clusters=cluster, random_state=10)
    cluster_labels = clusterer.fit_predict(x)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(x, cluster_labels)
    print("For n_clusters =", cluster,
          "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.6800089328668559
# For n_clusters = 3 The average silhouette_score is : 0.8354859444374256
# For n_clusters = 4 The average silhouette_score is : 0.6800693440196874
# For n_clusters = 5 The average silhouette_score is : 0.5186432768128583
# For n_clusters = 6 The average silhouette_score is : 0.3600869693440215

# %%
arr
# Out:
# 0.8354859444374256
