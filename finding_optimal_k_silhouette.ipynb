# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import numpy as np

# %%
x, y = make_blobs()
x.shape
# Out:
# (100, 2)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x[:,0],x[:,1],c = y)

# %%
from sklearn.metrics import silhouette_score

# %%
k_clusters = [2,3,4,5,6]
for cluster in k_clusters:
    clusterer = KMeans(n_clusters=cluster, random_state=10)
    cluster_labels = clusterer.fit_predict(x)
    silhouette_avg = silhouette_score(x, cluster_labels)
    print("For n_clusters =", cluster,
          "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.5754932877239165
# For n_clusters = 3 The average silhouette_score is : 0.6113679928642896
# For n_clusters = 4 The average silhouette_score is : 0.5085940758964793
# For n_clusters = 5 The average silhouette_score is : 0.4191141961841734
# For n_clusters = 6 The average silhouette_score is : 0.37683581793890136
