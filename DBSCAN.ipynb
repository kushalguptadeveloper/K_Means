# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN

# %%
x,y = make_blobs()

# %%
import matplotlib.pyplot as plt
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %%
dbscan = DBSCAN(eps=1.0)

# %%
dbscan.fit(x)
# Out:
# DBSCAN(algorithm='auto', eps=1.0, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=5, n_jobs=1, p=None)

# %%
dbscan.labels_
# Out:
# array([ 0,  1,  2, -1, -1,  0,  2,  0,  2,  0,  2,  2,  1,  2,  0,  0,  0,
#         2,  1,  2,  2,  2,  1,  1,  0,  2, -1,  0,  1,  1,  2,  2,  0,  2,
#         2,  0,  0,  0,  2, -1,  2,  0,  0,  1,  2,  2,  1,  2,  0,  2,  0,
#         1,  1,  1,  1,  0,  0,  2,  1,  2,  1,  1,  1,  2,  1,  1,  0,  2,
#        -1,  0,  2,  2,  2,  0,  2,  0,  0,  1,  0,  1, -1,  1,  1,  2, -1,
#         0, -1,  1,  0, -1,  1, -1,  1,  0,  2,  0,  0,  0,  0,  2])

# %%
for i in range(len(x)):
    if dbscan.labels_[i] == 0:
        plt.scatter(x[i,0],x[i,1],c='r',marker="+")
    elif dbscan.labels_[i] == 1:
        plt.scatter(x[i,0],x[i,1],c='g',marker="o")
    elif dbscan.labels_[i] == 2:
        plt.scatter(x[i,0],x[i,1],c='b',marker="*")
    elif dbscan.labels_[i] == -1:
        plt.scatter(x[i,0],x[i,1])
plt.show()
