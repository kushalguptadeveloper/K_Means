# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering

# %%
x,y = make_blobs()

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x[:,0],x[:,1],c = y)

# %%
aglo = AgglomerativeClustering(n_clusters = 3)

# %%
aglo.fit(x)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='ward', memory=None, n_clusters=3,
#             pooling_func=<function mean at 0x10c974c80>)

# %%
aglo.labels_
# Out:
# array([0, 2, 2, 2, 0, 1, 2, 0, 1, 2, 2, 0, 1, 1, 2, 0, 1, 2, 1, 2, 1, 2,
#        2, 2, 1, 0, 0, 0, 0, 0, 2, 1, 0, 1, 2, 1, 0, 0, 1, 1, 0, 1, 0, 0,
#        1, 2, 0, 1, 0, 0, 1, 2, 2, 1, 0, 0, 1, 2, 1, 2, 0, 0, 2, 1, 0, 1,
#        2, 1, 2, 0, 2, 1, 2, 1, 0, 1, 1, 2, 0, 2, 2, 2, 2, 1, 2, 1, 2, 1,
#        0, 1, 2, 0, 0, 0, 1, 0, 0, 2, 2, 1])
